# %%
from pydicom import dcmread

# %%
path = r"..\..\..\..\..\01_Datasets_Hot\01_External\PROSTATEx\images\ProstateX-0004\10-18-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-45493\3.000000-t2tsesag-00386\1-01.dcm"

# %%
first_dicom = dcmread(path)
first_dicom
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 196
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.7311.5101.294081267725134067317791529279
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# (0008, 0012) Instance Creation Date              DA: '20111018'
# (0008, 0013) Instance Creation Time              TM: '114505.406000'
# ...

# %%
type(first_dicom)
# Out:
# pydicom.dataset.FileDataset

# %%
# Since it is a pydicom.dataset.FileDataset object, we can access its attributes and methods to extract relevant information from the DICOM file.
# First, print the list of all attributes in the DICOM file.

dir(first_dicom)
# Out:
# ['AccessionNumber',
#  'AcquisitionDate',
#  'AcquisitionMatrix',
#  'AcquisitionNumber',
#  'AcquisitionTime',
#  'AngioFlag',
#  'BitsAllocated',
#  'BitsStored',
#  'BodyPartExamined',
#  'Columns',
#  'CommentsOnThePerformedProcedureStep',
#  'ContentDate',
#  'ContentTime',
#  'DeidentificationMethod',
#  'DeidentificationMethodCodeSequence',
#  'EchoNumbers',
#  'EchoTime',
#  'EchoTrainLength',
#  'FlipAngle',
#  'FrameOfReferenceUID',
#  'HighBit',
#  'ImageOrientationPatient',
#  'ImagePositionPatient',
#  'ImageType',
#  'ImagedNucleus',
#  'ImagingFrequency',
#  'InPlanePhaseEncodingDirection',
#  'InstanceCreationDate',
#  'InstanceCreationTime',
#  'InstanceNumber',
#  'LargestImagePixelValue',
#  'LongitudinalTemporalInformationModified',
#  'MRAcquisitionType',
#  'MagneticFieldStrength',
#  'Manufacturer',
#  'ManufacturerModelName',
#  'Modality',
#  'NumberOfAverages',
#  'NumberOfPhaseEncodingSteps',
#  'PatientAge',
#  'PatientBirthDate',
#  'PatientID',
# ...

# %%
# Example: pixel spacing
pixel_spacing = first_dicom.PixelSpacing
pixel_spacing
# Out:
# [0.5625, 0.5625]

# %%
print(first_dicom.pixel_array)
print()
print(first_dicom.pixel_array.shape)  # Print the shape of the pixel array
# Out:
# [[ 0  0  0 ...  0  0  0]
#  [ 0  5  1 ...  0  2  0]
#  [ 0  0  0 ...  2  1  0]
#  ...
#  [ 0 12 16 ...  0  0 83]
#  [ 0 15  7 ...  0  0 27]
#  [ 0  1  0 ...  0  6  1]]
#
# (320, 320)

# %%
import matplotlib.pyplot as plt

plt.imshow(first_dicom.pixel_array, cmap=plt.cm.gray)
plt.show()
